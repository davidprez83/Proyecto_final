# %% [markdown]
# # Proyecto de Mecánica Celeste: Aproximación de Apophis en 2029
#
# ## Plantilla de trabajo
#
# Esta libreta está pensada como una guía de estructura. No contiene celdas de código para que puedas organizar tu reporte con calma y luego insertar tus propios cálculos, figuras y resultados.
#
# Escribe aquí una introducción breve sobre el problema físico, el objetivo del proyecto y la idea general del análisis.

# %% [markdown]
# ## 1. Introducción
#
# En esta sección describe qué es Apophis, por qué su aproximación de 2029 es importante y qué pregunta científica vas a responder.
#
# Incluye un párrafo corto sobre el contexto astronómico y otro sobre el propósito del notebook.

# %% [markdown]
# ## 2. Objetivos
#
# Escribe aquí los objetivos generales y específicos del trabajo.
#
# Ejemplo de objetivos posibles:
# - Estimar la distancia mínima de aproximación.
# - Comparar una integración de N cuerpos con la teoría de dos cuerpos.
# - Comparar los resultados con efemérides de JPL.
# - Analizar el cambio orbital de Apophis antes y después del encuentro.

# %% [markdown]
# ## 3. Teoría base: problema de N cuerpos
#
# Explica aquí la idea física del problema de N cuerpos y por qué se usa para modelar el sistema solar.
#
# Incluye las ecuaciones que vayas a usar, por ejemplo:
#
# $$
# m_i\ddot{\mathbf r}_i = -\sum_{j\neq i} G\,m_i m_j\,\frac{\mathbf r_i-\mathbf r_j}{\lVert\mathbf r_i-\mathbf r_j\rVert^3}
# $$
#
# Describe qué aproximaciones estás haciendo y qué significa tratar a Apophis como partícula de prueba.

# %% [markdown]
# ## 4. Configuración del modelo numérico
#
# Aquí debes explicar cómo vas a construir tu simulación.
#
# Incluye en texto:
# - La fecha inicial de integración.
# - El intervalo temporal que vas a estudiar.
# - Qué cuerpos incluirás en el modelo.
# - Qué variables vas a guardar de cada cuerpo.
#
# Más adelante, en tu versión final, esta sección irá seguida por las celdas de código que hagan la integración.

# %% [markdown]
# ## 5. Cantidades indispensables para el análisis
#
# En esta sección escribe qué magnitudes vas a estudiar y por qué.
#
# Recomendación de cantidades clave:
# - Distancia mínima Apophis-Tierra.
# - Fecha y hora del máximo acercamiento.
# - Vector relativo posición-velocidad entre Apophis y la Tierra.
# - Elementos orbitales antes y después del encuentro.
# - Error respecto a JPL.
# - Cambios en energía y momento angular como control numérico.
#
# Explica aquí cuáles de estas cantidades sí son centrales para tu versión del proyecto y cuáles solo usarás como validación.

# %% [markdown]
# ## 6. Teoría base: problema de dos cuerpos
#
# Explica aquí por qué el problema de dos cuerpos sirve como primera aproximación para la órbita de Apophis alrededor del Sol.
#
# Incluye las ecuaciones que uses para energía, momento angular y elementos orbitales. Si vas a resolver la ecuación de Kepler, descríbelo aquí antes de poner código.
#
# Ejemplo de ecuación útil:
#
# $$
# M = E - e\sin E
# $$
#
# Explica también qué hipótesis hacen que esta teoría se vuelva insuficiente cerca del paso por la Tierra.

# %% [markdown]
# ## 7. Plano invariante y geometría orbital
#
# Aquí puedes explicar la idea del plano invariante de Laplace y la eclíptica.
#
# Si vas a usar estas referencias geométricas, escribe qué representa cada una y cómo se relacionan con la inclinación de la órbita de Apophis.
#
# Incluye las fórmulas que necesites para medir inclinaciones relativas entre planos.

# %% [markdown]
# ## 8. Comparación con JPL
#
# Explica aquí por qué usas JPL como referencia y qué aspecto de tus resultados vas a comparar contra sus efemérides.
#
# Aclara si compararás:
# - Posición.
# - Velocidad.
# - Distancia mínima.
# - Elementos orbitales.
#
# Escribe también qué interpretarás como un buen o mal acuerdo entre tu modelo y JPL.

# %% [markdown]
# ## 9. Validación numérica
#
# En esta sección describe qué usarás como chequeo de calidad de la integración.
#
# Lo normal es mostrar que la energía y el momento angular total no cambian demasiado.
#
# No hace falta desarrollar mucho esta parte; basta con explicar por qué sirve como prueba de consistencia interna del integrador.

# %% [markdown]
# ## 10. Resultados
#
# Aquí irán tus figuras y tus resultados más importantes.
#
# Te conviene dividir esta sección en subsecciones como estas:
# - Trayectorias.
# - Distancia mínima.
# - Comparación N cuerpos vs dos cuerpos.
# - Comparación con JPL.
# - Evolución de elementos orbitales.
#
# Antes de cada figura, escribe 2 o 3 líneas explicando qué muestra y cómo leerla.

# %% [markdown]
# ## 11. Discusión
#
# Interpreta tus resultados con palabras claras.
#
# Aquí no repitas solo lo que muestran las gráficas. Explica:
# - Qué método resultó más confiable.
# - Qué parte del análisis fue más sensible a errores.
# - Qué te dice el encuentro sobre la dinámica orbital de Apophis.
#
# Si algo no salió como esperabas, también se puede discutir, siempre que expliques por qué.

# %% [markdown]
# ## 12. Conclusiones
#
# Resume aquí tus hallazgos en forma de conclusiones cortas y directas.
#
# Procura responder explícitamente a la pregunta principal del proyecto y cerrar con 3 a 5 conclusiones puntuales.

# %% [markdown]
# ## 13. Anexo de fórmulas
#
# Usa esta sección si quieres dejar reunidas las ecuaciones principales del proyecto para consulta rápida.
#
# Puedes incluir aquí la definición de energía, momento angular, elementos orbitales o cualquier relación geométrica que vayas a usar varias veces.

# %% [markdown]
# ## 14. Espacio para notas personales
#
# Este espacio es opcional. Puedes usarlo para dejar recordatorios, pendientes o ideas de mejoras mientras construyes tu versión final del notebook.
#
# Cuando termines, puedes borrar esta sección si no la necesitas.
